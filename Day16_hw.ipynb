# %% [markdown]
# # Day16
# ## 模擬 HTTP 請求：使用 Requests 套件
# - 了解靜態網頁的爬蟲策略
# - 認識靜態網頁爬蟲的常用套件：Requests
# - Requests 套件實作練習

# %% [markdown]
# ## 作業說明
# 請跟著引導填空程式碼，練習以下題目
# 1. 練習發送 Requests
# 2. 練習帶上 headers
# 3. 練習帶上 payload

# %%
import requests

# %% [markdown]
# ### (1) 練習發送 Requests
# - Wordle
#
# https://www.nytimes.com/games/wordle/index.html

# %%
url = "https://www.nytimes.com/games/wordle/index.html"
r = requests.get(url)
r.encoding = 'utf-8'
print(r.text, "\n\n", r.text[500:1500])
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ### (2) 練習帶上 headers
# - Momo 購物網
#
# https://www.momoshop.com.tw/main/Main.jsp

# %%
url = "https://www.momoshop.com.tw/main/Main.jsp"

headers = {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
    "accept-encoding": "gzip, deflate, br", 
    "accept-language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6", 
    "cookie": "_fbp=fb.3.1741677086331.2033522205; CAD=1; searchKeyWordsHistory=%5B%22%E5%A5%B6%E6%B2%B9%E4%B9%B3%E9%85%AA%22%5D; _mwa_uniCampaignInfo=1739778742594959508.1739778742594; ARK_ID=JS5d060c57278fd00157e35622b98182745d06; wshop=wshop_web_c_8; JSESSIONID=690F6E0659B7FCF259B99E11AF1260DF-m1.c1-shop08; TN=undefined; CN=undefined; CM=undefined; firstTimeOpenShop=forever; bid=b61466be8f07aa40e2df72caae627b51; isBI=1; _gcl_au=1.1.1808262179.1741677084; _ga_BKEC67VMMG=GS1.1.1741677084.1.0.1741677084.60.0.0; _ga=GA1.1.590135878.1741677084; _edvid=0b0ce6b0-fe48-11ef-b112-8701245f99cc; _eds=1741677085; appier_utmz=%7B%7D; _atrk_siteuid=ypDn-SLvhTrNggXC; _atrk_ssid=C6dUt9TxzhHcEANEKd0whl; appier_pv_counterERlDyPL9yO7gfOb=0; appier_page_isView_ERlDyPL9yO7gfOb=f42a524e779bd74dc4d8c3f4c7cf713fea37ab2fbf23e346b8d74d9359dc7aea; appier_pv_counterc7279b5af7b77d1=0; appier_page_isView_c7279b5af7b77d1=f42a524e779bd74dc4d8c3f4c7cf713fea37ab2fbf23e346b8d74d9359dc7aea; _atrk_sessidx=3; cto_bundle=3-; _mwa_uniVisitorInfo=1698555207652574394.1698555207652.22.1741677086468; __rtbh.uid=%7B%22eventType%22%3A%22uid%22%2C%22id%22%3A%22unknown%22%2C%22expiryDate%22%3A%222026-03-11T07%3A11%3A26.476Z%22%7D; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%22j0CUVBTCOcXLXSWeI8VY%22%2C%22expiryDate%22%3A%222026-03-11T07%3A11%3A26.477Z%22%7D; _fbp=fb.3.1741677086331.2033522205; _mwa_uniSessionInfo=1741677086468990073.1741677086468.4.1741677087567; _vid=85d4c1de57c6d8236401196897634f2437efb4fa924da5fb27a231cfc57abcb09b4d94ce7336194efd87b5e26345e24c45364f4ec0a0229a10f28e885e91af2d345381bdfdf7453f0fd953e92ed21ca76840de604353c58c46b0e66fe19f7a14",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36 Edg/134.0.0.0",
}
r = requests.get(url, headers=headers)
r.encoding = 'utf-8'
print(r.text, "\n\n", r.text[500:1500])
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE HTML>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <html lang="zh">
# <head>
# <link rel="stylesheet" href="//image.momoshop.com.tw/ecm/css/ec-common/ec-reset.css?t=20240415001" type="text/css"/>
# <link rel="shortcut icon" href="/main/favicon.ico?t=20241022001"/>
# <link rel="Bookmark" href="/main/favicon.ico?t=20241022001"/>
# <link rel="icon" href="/main/favicon.ico?t=20241022001" type="image/ico"/>
# <link rel="search" href="/search/openSearch.xml" type="application/opensearchdescription+xml" title= momo購物網 - 好評推薦 - 2025年3月/>
#
#
# <link rel="canonical" href="https://www.momoshop.com.tw">
# <link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.momoshop.com.tw">
#
#
# <title>momo&#36092;&#29289;&#32178; - 好評推薦 - 2025年3月</title>
#
#
# <script type="application/ld+json">
# {
# ...

# %% [markdown]
# ### (3) 練習帶上 payload
# - CNYES 鉅亨網 新聞 API
#
# https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?startAt=1615478400&endAt=1646928000&limit=1000

# %%
import time
import datetime

start_date = datetime.datetime(2024, 3, 1, 0, 0, 0)
startAt = int(start_date.timestamp())

end_date = datetime.datetime(2025, 3, 31, 23, 59, 59)
endAt = int(end_date.timestamp())

url = "https://api.cnyes.com/media/api/v1/newslist/category/tw_stock"

params = {
    "startAt": startAt,  # 2024-03-01 00:00:00
    "endAt": endAt,      # 2025-03-31 23:59:59
    "limit": 1000        # 限制最多 1000 則新聞
}


headers = {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
    "accept-encoding": "gzip, deflate, br", 
    "accept-language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6", 
    "cookie": "_gid=GA1.2.1158846482.1741739500; _ga_G733DLJ15Z=GS1.1.1741739501.1.0.1741739501.60.0.0; _ga_Q14GZ4B1PW=GS1.1.1741739502.1.0.1741739502.0.0.0; _ga_102K295BQ2=GS1.1.1741739502.1.0.1741739502.60.0.0; _ga_YHSTW3NTRH=GS1.2.1741739503.1.0.1741739503.0.0.0; __gads=ID=3bd1d13d8cc2ec0f:T=1741739504:RT=1741739504:S=ALNI_MYie5zYsGFSxiBuxWrL08wDzd1YHg; __gpi=UID=0000105e228b9751:T=1741739504:RT=1741739504:S=ALNI_MYLo6nQdIpFcZJYx88Gt0BQzZpHdQ; __eoi=ID=0353feace8086720:T=1741739504:RT=1741739504:S=AA-AfjZG8QZ6PhXZigu6P989q8-X; _ga=GA1.1.925476790.1741739500; _ga_MHC8VFJ7Y6=GS1.1.1741739505.1.0.1741739505.60.0.0; FCNEC=%5B%5B%22AKsRol9xpbZEFjrx-D7Qhol_dyYXyr0rksgmDk8mXmoYEI1aOypckfOS3EgmzEfpbWWSG9qMRyyH34UZlxfKyWi9bM7X6gWokraZaoHWDSGV5PlmrVGxNjrQiTAsC3HgTwBRQipldKBLzxOsXbrfamVXfSizp6ePRw%3D%3D%22%5D%5D",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36 Edg/134.0.0.0"
}


r = requests.get(url, headers=headers, params=params)  
print(r.status_code)
data = r.json()
data["items"]["data"][0]
# Out:
# 200
# ...
