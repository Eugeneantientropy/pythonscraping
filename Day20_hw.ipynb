# %% [markdown]
# # Day20
# ## 網頁結構解析：使用 lxml 套件操作 XPath
# - 使用 lxml.html
# - 使用 XPath 語法獲取子節點

# %% [markdown]
# ## 作業說明
# 由於 Day18 作業我們已經練習過一些定位工具，今天使用和 Day19 一樣的網站，針對 XPath 更多變化用法再深入練習吧。
#
# - 題目網站：
# https://pokemondb.net/pokedex/all
# - 使用 XPath 技巧把寶可夢表格抓下來

# %%
import lxml.html
import requests

# %% [markdown]
# ### `GET` Request

# %%
url = "https://pokemondb.net/pokedex/all"
headers = {
   "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36",
   "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
   "Accept-Encoding": "gzip, deflate, br",
   "Accept-Language": "zh-TW,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6",
   "Cache-Control": "max-age=0",
   "Upgrade-Insecure-Requests": "1",
   "Referer": "https://pokemondb.net/",
   "X-Frame-Options": "SAMEORIGIN",
   "X-Content-Type-Options": "nosniff",
   "X-XSS-Protection": "1; mode=block"
}

r = requests.get(url, headers=headers)
r.encoding = 'utf-8'

print(r.status_code, "\n\n", r.text[:1000])
# Out:
# 200
#
#  <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="utf-8">
# 	<title>Pokémon Pokédex: list of Pokémon with stats | Pokémon Database</title>
#
# 	<link rel="preconnect" href="https://img.pokemondb.net">
# 	<link rel="preconnect" href="https://s.pokemondb.net">
# 	<link rel="preload" href="/static/fonts/fira-sans-v17-latin-400.woff2" as="font" type="font/woff2" crossorigin>
# 	<link rel="preload" href="/static/fonts/fira-sans-v17-latin-400i.woff2" as="font" type="font/woff2" crossorigin>
# 	<link rel="preload" href="/static/fonts/fira-sans-v17-latin-600.woff2" as="font" type="font/woff2" crossorigin>
# 		<link rel="stylesheet" href="/static/css/pokemondb-9acb309c4f.css">
#
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
#
# 	<meta property="og:description" name="description" content="The Pokédex contains detailed stats for every creature from the Pokémon games, up to and including the latest Scarlet/Violet games.">
# 	<link rel="canonical" href="https://pokemondb.net/pokedex/all">

# %% [markdown]
# ### 轉為 HTML Element 物件
# - 使用 `lxml.html.fromstring()`

# %%
# 轉為 Element 物件
tree = lxml.html.fromstring(r.content)
tree
# Out:
# <Element html at 0x28fb65bfa70>

# %% [markdown]
# ### 指定相符特徵的節點
# - 找到寶可夢資訊表格
# - 使用：`tree.xpath('//<tag_name>[@<attribute>=<attribute_value>]')`

# %%
# Hint: 
# table = tree.xpath('//table[@id="_____"]')[0]
table = tree.xpath('//table[@id="pokedex"]')[0]
table
# Out:
# <Element table at 0x28fb65bf9d0>

# %% [markdown]
# ### 連續查找
# - 取得所有表格中的列

# %%
# Hint: 
# header = table.xpath("./_____")[0].xpath(".//__")
# body_rows = table.xpath("./_____")[0].xpath(".//__")

header = table.xpath("./thead")[0].xpath(".//th")
body_rows = table.xpath("./tbody")[0].xpath(".//tr")

# %%
header
# Out:
# [<Element th at 0x28fb681b700>,
#  <Element th at 0x28fb6818190>,
#  <Element th at 0x28fb681b520>,
#  <Element th at 0x28fb681b250>,
#  <Element th at 0x28fb681a490>,
#  <Element th at 0x28fb681b930>,
#  <Element th at 0x28fb681a760>,
#  <Element th at 0x28fb681b430>,
#  <Element th at 0x28fb681bde0>,
#  <Element th at 0x28fb681bac0>]

# %%
body_rows
# Out:
# [<Element tr at 0x28fbadc3c50>,
#  <Element tr at 0x28fbadc28a0>,
#  <Element tr at 0x28fbadc3ca0>,
#  <Element tr at 0x28fbadc3e80>,
#  <Element tr at 0x28fbadc2e40>,
#  <Element tr at 0x28fbadc3390>,
#  <Element tr at 0x28fbadc3c00>,
#  <Element tr at 0x28fbadc35c0>,
#  <Element tr at 0x28fbadc3b10>,
#  <Element tr at 0x28fbadc2080>,
#  <Element tr at 0x28fbadc1950>,
#  <Element tr at 0x28fbadc1d10>,
#  <Element tr at 0x28fbadc1d60>,
#  <Element tr at 0x28fbadc1ea0>,
#  <Element tr at 0x28fbadc1e50>,
#  <Element tr at 0x28fbadc18b0>,
#  <Element tr at 0x28fbadc19a0>,
#  <Element tr at 0x28fbadc1220>,
#  <Element tr at 0x28fbadc1270>,
#  <Element tr at 0x28fbadc12c0>,
#  <Element tr at 0x28fbadc1a90>,
#  <Element tr at 0x28fbadc1cc0>,
#  <Element tr at 0x28fbadc1860>,
#  <Element tr at 0x28fbadc11d0>,
#  <Element tr at 0x28fbadc1ae0>,
#  <Element tr at 0x28fbadc0690>,
#  <Element tr at 0x28fbadc0410>,
#  <Element tr at 0x28fbadc09b0>,
#  <Element tr at 0x28fbadc0a50>,
#  <Element tr at 0x28fbadc0dc0>,
#  <Element tr at 0x28fbadc0e60>,
#  <Element tr at 0x28fbadc0e10>,
#  <Element tr at 0x28fbada8e10>,
#  <Element tr at 0x28fbada82d0>,
#  <Element tr at 0x28fbadaa530>,
#  <Element tr at 0x28fbadab4d0>,
#  <Element tr at 0x28fbadab3e0>,
#  <Element tr at 0x28fbadabe30>,
#  <Element tr at 0x28fbadaac60>,
#  <Element tr at 0x28fbadaba70>,
#  <Element tr at 0x28fbadabf70>,
#  <Element tr at 0x28fbadab250>,
#  <Element tr at 0x28fbadabe80>,
#  <Element tr at 0x28fbadab700>,
#  <Element tr at 0x28fbadab980>,
#  <Element tr at 0x28fbadab7a0>,
#  <Element tr at 0x28fbada8320>,
#  <Element tr at 0x28fbada86e0>,
#  <Element tr at 0x28fbada87d0>,
#  <Element tr at 0x28fbada89b0>,
#  <Element tr at 0x28fbada8a00>,
#  <Element tr at 0x28fbada8af0>,
#  <Element tr at 0x28fbada8b40>,
#  <Element tr at 0x28fbada8d70>,
#  <Element tr at 0x28fbada8e60>,
#  <Element tr at 0x28fbada8eb0>,
#  <Element tr at 0x28fbada8f00>,
#  <Element tr at 0x28fbada8f50>,
#  <Element tr at 0x28fbada8ff0>,
#  <Element tr at 0x28fbada9040>,
#  <Element tr at 0x28fbada9130>,
#  <Element tr at 0x28fbada9180>,
#  <Element tr at 0x28fbada91d0>,
#  <Element tr at 0x28fbada9860>,
#  <Element tr at 0x28fbada9810>,
#  <Element tr at 0x28fbada99f0>,
#  <Element tr at 0x28fbadaa800>,
#  <Element tr at 0x28fbadaad50>,
#  <Element tr at 0x28fbadaa620>,
#  <Element tr at 0x28fbada8910>,
#  <Element tr at 0x28fbada8960>,
#  <Element tr at 0x28fbada83c0>,
#  <Element tr at 0x28fbada8500>,
#  <Element tr at 0x28fbada8550>,
#  <Element tr at 0x28fbada85a0>,
#  <Element tr at 0x28fbada8640>,
#  <Element tr at 0x28fbada8730>,
#  <Element tr at 0x28fbada8780>,
#  <Element tr at 0x28fbadabed0>,
#  <Element tr at 0x28fbada8140>,
#  <Element tr at 0x28fbada8190>,
#  <Element tr at 0x28fbada8230>,
#  <Element tr at 0x28fbada81e0>,
#  <Element tr at 0x28fbada8370>,
#  <Element tr at 0x28fbada8690>,
#  <Element tr at 0x28fbadaa6c0>,
#  <Element tr at 0x28fbada8280>,
#  <Element tr at 0x28fbadaa670>,
#  <Element tr at 0x28fbada8460>,
#  <Element tr at 0x28fbada9d10>,
#  <Element tr at 0x28fbadab430>,
#  <Element tr at 0x28fbadab570>,
#  <Element tr at 0x28fbadab840>,
#  <Element tr at 0x28fbadabbb0>,
#  <Element tr at 0x28fbadabca0>,
#  <Element tr at 0x28fbadabcf0>,
#  <Element tr at 0x28fbadaaee0>,
#  <Element tr at 0x28fbadab2f0>,
#  <Element tr at 0x28fbadab160>,
#  <Element tr at 0x28fbadab5c0>,
#  <Element tr at 0x28fbadaba20>,
#  <Element tr at 0x28fbadaa8a0>,
#  <Element tr at 0x28fbadab110>,
#  <Element tr at 0x28fbadab480>,
#  <Element tr at 0x28fbadabf20>,
#  <Element tr at 0x28fbadabd90>,
#  <Element tr at 0x28fbadaa210>,
#  <Element tr at 0x28fbadaaa30>,
#  <Element tr at 0x28fbadaa1c0>,
#  <Element tr at 0x28fbada99a0>,
#  <Element tr at 0x28fbadaa8f0>,
#  <Element tr at 0x28fbadab070>,
#  <Element tr at 0x28fbadab020>,
#  <Element tr at 0x28fbadab930>,
#  <Element tr at 0x28fbadab8e0>,
#  <Element tr at 0x28fbadab9d0>,
#  <Element tr at 0x28fbada9f90>,
#  <Element tr at 0x28fbadaa120>,
#  <Element tr at 0x28fbada9fe0>,
#  <Element tr at 0x28fbadaa0d0>,
#  <Element tr at 0x28fbada9400>,
#  <Element tr at 0x28fbada9450>,
#  <Element tr at 0x28fbada93b0>,
#  <Element tr at 0x28fbada9b30>,
#  <Element tr at 0x28fbada9ae0>,
#  <Element tr at 0x28fbada98b0>,
#  <Element tr at 0x28fbada9900>,
#  <Element tr at 0x28fbada92c0>,
#  <Element tr at 0x28fbada90e0>,
#  <Element tr at 0x28fbada9310>,
#  <Element tr at 0x28fbada97c0>,
#  <Element tr at 0x28fbada9720>,
#  <Element tr at 0x28fbada9770>,
#  <Element tr at 0x28fbada9540>,
#  <Element tr at 0x28fbada9590>,
#  <Element tr at 0x28fbada8cd0>,
#  <Element tr at 0x28fbada8d20>,
#  <Element tr at 0x28fbada94f0>,
#  <Element tr at 0x28fbada88c0>,
#  <Element tr at 0x28fbada84b0>,
#  <Element tr at 0x28fbada8870>,
#  <Element tr at 0x28fbada8a50>,
#  <Element tr at 0x28fbada8aa0>,
#  <Element tr at 0x28fbada8be0>,
#  <Element tr at 0x28fbada8c30>,
#  <Element tr at 0x28fbada8c80>,
#  <Element tr at 0x28fbadaa940>,
#  <Element tr at 0x28fbada9090>,
#  <Element tr at 0x28fbadcba20>,
#  <Element tr at 0x28fbadcaee0>,
#  <Element tr at 0x28fbadcafd0>,
#  <Element tr at 0x28fbadcb660>,
#  <Element tr at 0x28fbadcb160>,
#  <Element tr at 0x28fbadc8910>,
#  <Element tr at 0x28fbadc8870>,
#  <Element tr at 0x28fbadcb200>,
#  <Element tr at 0x28fbadcbc00>,
#  <Element tr at 0x28fbadcadf0>,
#  <Element tr at 0x28fbadcb0c0>,
#  <Element tr at 0x28fbadc87d0>,
#  <Element tr at 0x28fbadcac10>,
#  <Element tr at 0x28fbadcac60>,
#  <Element tr at 0x28fbadc8e10>,
#  <Element tr at 0x28fbadc9090>,
#  <Element tr at 0x28fbadc8af0>,
#  <Element tr at 0x28fbadc8460>,
#  <Element tr at 0x28fbadc8140>,
#  <Element tr at 0x28fbadcaa80>,
#  <Element tr at 0x28fbadcaf80>,
#  <Element tr at 0x28fbadcbde0>,
#  <Element tr at 0x28fbadcb4d0>,
#  <Element tr at 0x28fbadcad00>,
#  <Element tr at 0x28fbadcad50>,
#  <Element tr at 0x28fbadc83c0>,
#  <Element tr at 0x28fbadc80f0>,
#  <Element tr at 0x28fbadcb520>,
#  <Element tr at 0x28fbadcbb10>,
#  <Element tr at 0x28fbadcbc50>,
#  <Element tr at 0x28fbadcb700>,
#  <Element tr at 0x28fbadcbd90>,
#  <Element tr at 0x28fbadca760>,
#  <Element tr at 0x28fbadc9e50>,
#  <Element tr at 0x28fbadca8f0>,
#  <Element tr at 0x28fbadca8a0>,
#  <Element tr at 0x28fbadca170>,
#  <Element tr at 0x28fbadca210>,
#  <Element tr at 0x28fbadca1c0>,
#  <Element tr at 0x28fbadca0d0>,
#  <Element tr at 0x28fbadc9ea0>,
#  <Element tr at 0x28fbadca080>,
#  <Element tr at 0x28fbadca6c0>,
#  <Element tr at 0x28fbadca670>,
#  <Element tr at 0x28fbadca530>,
#  <Element tr at 0x28fbadca580>,
#  <Element tr at 0x28fbadca4e0>,
#  <Element tr at 0x28fbadca350>,
#  <Element tr at 0x28fbadca2b0>,
#  <Element tr at 0x28fbadca300>,
#  <Element tr at 0x28fbadc9ae0>,
#  <Element tr at 0x28fbadc9a90>,
#  <Element tr at 0x28fbadc9a40>,
#  <Element tr at 0x28fbadc99f0>,
#  <Element tr at 0x28fbadc99a0>,
#  <Element tr at 0x28fbadc9860>,
#  <Element tr at 0x28fbadc9810>,
#  <Element tr at 0x28fbadc9630>,
#  <Element tr at 0x28fbadc9680>,
#  <Element tr at 0x28fbadc95e0>,
#  <Element tr at 0x28fbadc9270>,
#  <Element tr at 0x28fbadc91d0>,
#  <Element tr at 0x28fbadc8eb0>,
#  <Element tr at 0x28fbadc8e60>,
#  <Element tr at 0x28fbadc8dc0>,
#  <Element tr at 0x28fbadc8cd0>,
#  <Element tr at 0x28fbadc8c80>,
#  <Element tr at 0x28fbadc8c30>,
#  <Element tr at 0x28fbadc89b0>,
#  <Element tr at 0x28fbadc8960>,
#  <Element tr at 0x28fbadcb750>,
#  <Element tr at 0x28fbadcbd40>,
#  <Element tr at 0x28fbadcb570>,
#  <Element tr at 0x28fbadcaad0>,
#  <Element tr at 0x28fbadc9220>,
#  <Element tr at 0x28fbadcab70>,
#  <Element tr at 0x28fbadc8190>,
#  <Element tr at 0x28fbadc84b0>,
#  <Element tr at 0x28fbadcb340>,
#  <Element tr at 0x28fbadcbb60>,
#  <Element tr at 0x28fbadcae40>,
#  <Element tr at 0x28fbadc80a0>,
#  <Element tr at 0x28fbadc8320>,
#  <Element tr at 0x28fbadc8410>,
#  <Element tr at 0x28fbadc81e0>,
#  <Element tr at 0x28fbadc8230>,
#  <Element tr at 0x28fbadc8280>,
#  <Element tr at 0x28fbadc8370>,
#  <Element tr at 0x28fbadc82d0>,
#  <Element tr at 0x28fbadc8050>,
#  <Element tr at 0x28fbadcb5c0>,
#  <Element tr at 0x28fbadcb480>,
#  <Element tr at 0x28fbadca800>,
#  <Element tr at 0x28fbadcb070>,
#  <Element tr at 0x28fbadcbca0>,
#  <Element tr at 0x28fbadcbbb0>,
#  <Element tr at 0x28fbadca9e0>,
#  <Element tr at 0x28fbadca940>,
#  <Element tr at 0x28fbadca850>,
#  <Element tr at 0x28fbadca120>,
#  <Element tr at 0x28fbadca7b0>,
#  <Element tr at 0x28fbadca710>,
#  <Element tr at 0x28fbadca3f0>,
#  <Element tr at 0x28fbadca260>,
#  <Element tr at 0x28fbadca030>,
#  <Element tr at 0x28fbadc9d60>,
#  <Element tr at 0x28fbadc9b80>,
#  <Element tr at 0x28fbadc9c70>,
#  <Element tr at 0x28fbadc9950>,
#  <Element tr at 0x28fbadc93b0>,
#  <Element tr at 0x28fbadca620>,
#  <Element tr at 0x28fbadca5d0>,
#  <Element tr at 0x28fbadca490>,
#  <Element tr at 0x28fbadca440>,
#  <Element tr at 0x28fbadca3a0>,
#  <Element tr at 0x28fbadc9fe0>,
#  <Element tr at 0x28fbadc9f90>,
#  <Element tr at 0x28fbadc9f40>,
#  <Element tr at 0x28fbadc9ef0>,
#  <Element tr at 0x28fbadc9e00>,
#  <Element tr at 0x28fbadc9db0>,
#  <Element tr at 0x28fbadc9d10>,
#  <Element tr at 0x28fbadc9cc0>,
#  <Element tr at 0x28fbadc94a0>,
#  <Element tr at 0x28fbadc9c20>,
#  <Element tr at 0x28fbadc9b30>,
#  <Element tr at 0x28fbadc9900>,
#  <Element tr at 0x28fbadc98b0>,
#  <Element tr at 0x28fbadc97c0>,
#  <Element tr at 0x28fbadc9770>,
#  <Element tr at 0x28fbadc96d0>,
#  <Element tr at 0x28fbadc9720>,
#  <Element tr at 0x28fbadc9590>,
#  <Element tr at 0x28fbadc9540>,
#  <Element tr at 0x28fbadc94f0>,
#  <Element tr at 0x28fbadc9360>,
#  <Element tr at 0x28fbadc9450>,
#  <Element tr at 0x28fbadc9400>,
#  <Element tr at 0x28fbadc92c0>,
#  <Element tr at 0x28fbadc9310>,
#  <Element tr at 0x28fbadc9130>,
#  <Element tr at 0x28fbadc9180>,
#  <Element tr at 0x28fbadc90e0>,
#  <Element tr at 0x28fbadc9040>,
#  <Element tr at 0x28fbadc8ff0>,
#  <Element tr at 0x28fbadc8fa0>,
#  <Element tr at 0x28fbadc8f50>,
#  <Element tr at 0x28fbadc8f00>,
#  <Element tr at 0x28fbadc8d70>,
#  <Element tr at 0x28fbadc8d20>,
#  <Element tr at 0x28fbadc8be0>,
#  <Element tr at 0x28fbadc8b90>,
#  <Element tr at 0x28fbadc8a50>,
#  <Element tr at 0x28fbadc8b40>,
#  <Element tr at 0x28fbadc8a00>,
#  <Element tr at 0x28fbadcb1b0>,
#  <Element tr at 0x28fbadc9bd0>,
#  <Element tr at 0x28fbadcb390>,
#  <Element tr at 0x28fbadc8780>,
#  <Element tr at 0x28fbadc8500>,
#  <Element tr at 0x28fbadcb020>,
#  <Element tr at 0x28fbadc86e0>,
#  <Element tr at 0x28fbadc8690>,
#  <Element tr at 0x28fbadcb430>,
#  <Element tr at 0x28fbadc8730>,
#  <Element tr at 0x28fbadcbac0>,
#  <Element tr at 0x28fbadcada0>,
#  <Element tr at 0x28fbadc85f0>,
#  <Element tr at 0x28fbadcae90>,
#  <Element tr at 0x28fbadc85a0>,
#  <Element tr at 0x28fbadc8640>,
#  <Element tr at 0x28fbadcb110>,
#  <Element tr at 0x28fbae06170>,
#  <Element tr at 0x28fbae04870>,
#  <Element tr at 0x28fbae048c0>,
#  <Element tr at 0x28fbae04910>,
#  <Element tr at 0x28fbae04960>,
#  <Element tr at 0x28fbae049b0>,
#  <Element tr at 0x28fbae04a00>,
#  <Element tr at 0x28fbae04a50>,
#  <Element tr at 0x28fbae04aa0>,
#  <Element tr at 0x28fbae04af0>,
#  <Element tr at 0x28fbae04b40>,
#  <Element tr at 0x28fbae04b90>,
#  <Element tr at 0x28fbae04be0>,
#  <Element tr at 0x28fbae04c30>,
#  <Element tr at 0x28fbae04c80>,
#  <Element tr at 0x28fbae04cd0>,
#  <Element tr at 0x28fbae04d20>,
#  <Element tr at 0x28fbae04d70>,
#  <Element tr at 0x28fbae04dc0>,
#  <Element tr at 0x28fbae04e60>,
#  <Element tr at 0x28fbae04e10>,
#  <Element tr at 0x28fbae04eb0>,
#  <Element tr at 0x28fbae04f00>,
#  <Element tr at 0x28fbae04f50>,
#  <Element tr at 0x28fbae04fa0>,
#  <Element tr at 0x28fbae04ff0>,
#  <Element tr at 0x28fbae05040>,
#  <Element tr at 0x28fbae050e0>,
#  <Element tr at 0x28fbae05090>,
#  <Element tr at 0x28fbae05130>,
#  <Element tr at 0x28fbae05180>,
#  <Element tr at 0x28fbae05220>,
#  <Element tr at 0x28fbae051d0>,
#  <Element tr at 0x28fbae052c0>,
#  <Element tr at 0x28fbae05270>,
#  <Element tr at 0x28fbae05360>,
#  <Element tr at 0x28fbae053b0>,
#  <Element tr at 0x28fbae05310>,
#  <Element tr at 0x28fbae05450>,
#  <Element tr at 0x28fbae054a0>,
#  <Element tr at 0x28fbae054f0>,
#  <Element tr at 0x28fbae05540>,
#  <Element tr at 0x28fbae05590>,
#  <Element tr at 0x28fbae055e0>,
#  <Element tr at 0x28fbae05630>,
#  <Element tr at 0x28fbae05680>,
#  <Element tr at 0x28fbae056d0>,
#  <Element tr at 0x28fbae05720>,
#  <Element tr at 0x28fbae05770>,
#  <Element tr at 0x28fbae05400>,
#  <Element tr at 0x28fbae05810>,
#  <Element tr at 0x28fbae05860>,
#  <Element tr at 0x28fbae058b0>,
#  <Element tr at 0x28fbae05900>,
#  <Element tr at 0x28fbae05950>,
#  <Element tr at 0x28fbae059a0>,
#  <Element tr at 0x28fbae059f0>,
#  <Element tr at 0x28fbae05a40>,
#  <Element tr at 0x28fbae05a90>,
#  <Element tr at 0x28fbae05ae0>,
#  <Element tr at 0x28fbae05b30>,
#  <Element tr at 0x28fbae05b80>,
#  <Element tr at 0x28fbae05bd0>,
#  <Element tr at 0x28fbae05c20>,
#  <Element tr at 0x28fbae05c70>,
#  <Element tr at 0x28fbae057c0>,
#  <Element tr at 0x28fbae05cc0>,
#  <Element tr at 0x28fbae05d10>,
#  <Element tr at 0x28fbae05d60>,
#  <Element tr at 0x28fbae05e00>,
#  <Element tr at 0x28fbae05e50>,
#  <Element tr at 0x28fbae05ea0>,
#  <Element tr at 0x28fbae05ef0>,
#  <Element tr at 0x28fbae05db0>,
#  <Element tr at 0x28fbae05f90>,
#  <Element tr at 0x28fbae05fe0>,
#  <Element tr at 0x28fbae06030>,
#  <Element tr at 0x28fbae06080>,
#  <Element tr at 0x28fbae060d0>,
#  <Element tr at 0x28fbae06120>,
#  <Element tr at 0x28fbae05f40>,
#  <Element tr at 0x28fbae061c0>,
#  <Element tr at 0x28fbae06210>,
#  <Element tr at 0x28fbae06260>,
#  <Element tr at 0x28fbae062b0>,
#  <Element tr at 0x28fbae06300>,
#  <Element tr at 0x28fbae06350>,
#  <Element tr at 0x28fbae063f0>,
#  <Element tr at 0x28fbae063a0>,
#  <Element tr at 0x28fbae06440>,
#  <Element tr at 0x28fbae06490>,
#  <Element tr at 0x28fbae064e0>,
#  <Element tr at 0x28fbae06530>,
#  <Element tr at 0x28fbae075c0>,
#  <Element tr at 0x28fbae07570>,
#  <Element tr at 0x28fbae07520>,
#  <Element tr at 0x28fbae074d0>,
#  <Element tr at 0x28fbae07160>,
#  <Element tr at 0x28fbae07110>,
#  <Element tr at 0x28fbae070c0>,
#  <Element tr at 0x28fbae07070>,
#  <Element tr at 0x28fbae07020>,
#  <Element tr at 0x28fbae06f80>,
#  <Element tr at 0x28fbae07ac0>,
#  <Element tr at 0x28fbae07700>,
#  <Element tr at 0x28fbae07890>,
#  <Element tr at 0x28fbae07430>,
#  <Element tr at 0x28fbae072a0>,
#  <Element tr at 0x28fbae07750>,
#  <Element tr at 0x28fbae077a0>,
#  <Element tr at 0x28fbae077f0>,
#  <Element tr at 0x28fbae07840>,
#  <Element tr at 0x28fbae07930>,
#  <Element tr at 0x28fbae07bb0>,
#  <Element tr at 0x28fbae07a70>,
#  <Element tr at 0x28fbae07b60>,
#  <Element tr at 0x28fbae079d0>,
#  <Element tr at 0x28fbae07a20>,
#  <Element tr at 0x28fbae07c50>,
#  <Element tr at 0x28fbae07ca0>,
#  <Element tr at 0x28fbae07980>,
#  <Element tr at 0x28fbae07f20>,
#  <Element tr at 0x28fbae07ed0>,
#  <Element tr at 0x28fbae07f70>,
#  <Element tr at 0x28fbae07fc0>,
#  <Element tr at 0x28fbae07d90>,
#  <Element tr at 0x28fbae07d40>,
#  <Element tr at 0x28fbae07660>,
#  <Element tr at 0x28fbae076b0>,
#  <Element tr at 0x28fbadffe80>,
#  <Element tr at 0x28fbadffe30>,
#  <Element tr at 0x28fbadfcd70>,
#  <Element tr at 0x28fbadff7a0>,
#  <Element tr at 0x28fbadff4d0>,
#  <Element tr at 0x28fbadff2a0>,
#  <Element tr at 0x28fbadff1b0>,
#  <Element tr at 0x28fbadff0c0>,
#  <Element tr at 0x28fbadfefd0>,
#  <Element tr at 0x28fbadfef80>,
#  <Element tr at 0x28fbadfef30>,
#  <Element tr at 0x28fbadfeee0>,
#  <Element tr at 0x28fbadfee90>,
#  <Element tr at 0x28fbadfee40>,
#  <Element tr at 0x28fbadfedf0>,
#  <Element tr at 0x28fbadfeda0>,
#  <Element tr at 0x28fbadfeb20>,
#  <Element tr at 0x28fbadfe8a0>,
#  <Element tr at 0x28fbadfe7b0>,
#  <Element tr at 0x28fbadfe6c0>,
#  <Element tr at 0x28fbadfe670>,
#  <Element tr at 0x28fbadfe620>,
#  <Element tr at 0x28fbadfe5d0>,
#  <Element tr at 0x28fbadfe580>,
#  <Element tr at 0x28fbadfe530>,
#  <Element tr at 0x28fbadfe4e0>,
#  <Element tr at 0x28fbadfe490>,
#  <Element tr at 0x28fbadfe440>,
#  <Element tr at 0x28fbadfe3f0>,
#  <Element tr at 0x28fbadfe3a0>,
#  <Element tr at 0x28fbadfe350>,
#  <Element tr at 0x28fbadfe300>,
#  <Element tr at 0x28fbadfe2b0>,
#  <Element tr at 0x28fbadfe0d0>,
#  <Element tr at 0x28fbadfe120>,
#  <Element tr at 0x28fbadfddb0>,
#  <Element tr at 0x28fbadfdb30>,
#  <Element tr at 0x28fbadfd9a0>,
#  <Element tr at 0x28fbadff020>,
#  <Element tr at 0x28fbadfe760>,
#  <Element tr at 0x28fbadfe710>,
#  <Element tr at 0x28fbadfea80>,
#  <Element tr at 0x28fbadfea30>,
#  <Element tr at 0x28fbadfe9e0>,
#  <Element tr at 0x28fbadfe990>,
#  <Element tr at 0x28fbadfe940>,
#  <Element tr at 0x28fbadfe850>,
#  <Element tr at 0x28fbadfe800>,
#  <Element tr at 0x28fbadfed00>,
#  <Element tr at 0x28fbadfecb0>,
#  <Element tr at 0x28fbadfec60>,
#  <Element tr at 0x28fbadfec10>,
#  <Element tr at 0x28fbadfebc0>,
#  <Element tr at 0x28fbadfead0>,
#  <Element tr at 0x28fbadfe8f0>,
#  <Element tr at 0x28fbadfed50>,
#  <Element tr at 0x28fbadfeb70>,
#  <Element tr at 0x28fbadff070>,
#  <Element tr at 0x28fbadff750>,
#  <Element tr at 0x28fbadff700>,
#  <Element tr at 0x28fbadff160>,
#  <Element tr at 0x28fbadff110>,
#  <Element tr at 0x28fbadff430>,
#  <Element tr at 0x28fbadff3e0>,
#  <Element tr at 0x28fbadff390>,
#  <Element tr at 0x28fbadff340>,
#  <Element tr at 0x28fbadff250>,
#  <Element tr at 0x28fbadff200>,
#  <Element tr at 0x28fbadff660>,
#  <Element tr at 0x28fbadff610>,
#  <Element tr at 0x28fbadff5c0>,
#  <Element tr at 0x28fbadff570>,
#  <Element tr at 0x28fbadff480>,
#  <Element tr at 0x28fbadff2f0>,
#  <Element tr at 0x28fbadff6b0>,
#  <Element tr at 0x28fbadff520>,
#  <Element tr at 0x28fbadff980>,
#  <Element tr at 0x28fbadffb60>,
#  <Element tr at 0x28fbadff930>,
#  <Element tr at 0x28fbadffed0>,
#  <Element tr at 0x28fbadffde0>,
#  <Element tr at 0x28fbadffd90>,
#  <Element tr at 0x28fbadffd40>,
#  <Element tr at 0x28fbadffcf0>,
#  <Element tr at 0x28fbadffca0>,
#  <Element tr at 0x28fbadffc50>,
#  <Element tr at 0x28fbadff8e0>,
#  <Element tr at 0x28fbadff890>,
#  <Element tr at 0x28fbadff840>,
#  <Element tr at 0x28fbadff7f0>,
#  <Element tr at 0x28fbade3bb0>,
#  <Element tr at 0x28fbade3de0>,
#  <Element tr at 0x28fbade3ed0>,
#  <Element tr at 0x28fbade3fc0>,
#  <Element tr at 0x28fbade3930>,
#  <Element tr at 0x28fbade3cf0>,
#  <Element tr at 0x28fbade3f20>,
#  <Element tr at 0x28fbade3f70>,
#  <Element tr at 0x28fbade3c50>,
#  <Element tr at 0x28fbade38e0>,
#  <Element tr at 0x28fbade3ca0>,
#  <Element tr at 0x28fbade17c0>,
#  <Element tr at 0x28fbade3d40>,
#  <Element tr at 0x28fbade3e30>,
#  <Element tr at 0x28fbade3c00>,
#  <Element tr at 0x28fbade3e80>,
#  <Element tr at 0x28fbade3a70>,
#  <Element tr at 0x28fbade3ac0>,
#  <Element tr at 0x28fbade3b10>,
#  <Element tr at 0x28fbade2ee0>,
#  <Element tr at 0x28fbade0b40>,
#  <Element tr at 0x28fbade0cd0>,
#  <Element tr at 0x28fbade0d70>,
#  <Element tr at 0x28fbade0dc0>,
#  <Element tr at 0x28fbade10e0>,
#  <Element tr at 0x28fbade1180>,
#  <Element tr at 0x28fbade14f0>,
#  <Element tr at 0x28fbade1590>,
#  <Element tr at 0x28fbade1540>,
#  <Element tr at 0x28fbade1720>,
#  <Element tr at 0x28fbade1770>,
#  <Element tr at 0x28fbade18b0>,
#  <Element tr at 0x28fbade1900>,
#  <Element tr at 0x28fbade1950>,
#  <Element tr at 0x28fbade19a0>,
#  <Element tr at 0x28fbade2440>,
#  <Element tr at 0x28fbade23f0>,
#  <Element tr at 0x28fbade27b0>,
#  <Element tr at 0x28fbade0500>,
#  <Element tr at 0x28fbade0280>,
#  <Element tr at 0x28fbade05f0>,
#  <Element tr at 0x28fbade2df0>,
#  <Element tr at 0x28fbade3d90>,
#  <Element tr at 0x28fbade39d0>,
#  <Element tr at 0x28fbade3b60>,
#  <Element tr at 0x28fbade3700>,
#  <Element tr at 0x28fbade3570>,
#  <Element tr at 0x28fbade3a20>,
#  <Element tr at 0x28fbade0b90>,
#  <Element tr at 0x28fbade0be0>,
#  <Element tr at 0x28fbade0870>,
#  <Element tr at 0x28fbade08c0>,
#  <Element tr at 0x28fbae13ca0>,
#  <Element tr at 0x28fbae12530>,
#  <Element tr at 0x28fbae120d0>,
#  <Element tr at 0x28fbae11d60>,
#  <Element tr at 0x28fbae11590>,
#  <Element tr at 0x28fbae107d0>,
#  <Element tr at 0x28fbae108c0>,
#  <Element tr at 0x28fbae109b0>,
#  <Element tr at 0x28fbae10aa0>,
#  <Element tr at 0x28fbae10af0>,
#  <Element tr at 0x28fbae10b40>,
#  <Element tr at 0x28fbae10d20>,
#  <Element tr at 0x28fbae10cd0>,
#  <Element tr at 0x28fbae10690>,
#  <Element tr at 0x28fbae106e0>,
#  <Element tr at 0x28fbae10370>,
#  <Element tr at 0x28fbae10140>,
#  <Element tr at 0x28fbae10a50>,
#  <Element tr at 0x28fbae101e0>,
#  <Element tr at 0x28fbae10230>,
#  <Element tr at 0x28fbae10320>,
#  <Element tr at 0x28fbae10500>,
#  <Element tr at 0x28fbae100a0>,
#  <Element tr at 0x28fbae10410>,
#  <Element tr at 0x28fbae10460>,
#  <Element tr at 0x28fbae104b0>,
#  <Element tr at 0x28fbae105f0>,
#  <Element tr at 0x28fbae105a0>,
#  <Element tr at 0x28fbae10190>,
#  <Element tr at 0x28fbae10280>,
#  <Element tr at 0x28fbae103c0>,
#  <Element tr at 0x28fbae100f0>,
#  <Element tr at 0x28fbae10a00>,
#  <Element tr at 0x28fbae11db0>,
#  <Element tr at 0x28fbae12030>,
#  <Element tr at 0x28fbae10910>,
#  <Element tr at 0x28fbae10960>,
#  <Element tr at 0x28fbae102d0>,
#  <Element tr at 0x28fbae10550>,
#  <Element tr at 0x28fbae10640>,
#  <Element tr at 0x28fbae10730>,
#  <Element tr at 0x28fbae10820>,
#  <Element tr at 0x28fbae10870>,
#  <Element tr at 0x28fbae13a20>,
#  <Element tr at 0x28fbae13890>,
#  <Element tr at 0x28fbae139d0>,
#  <Element tr at 0x28fbae13930>,
#  <Element tr at 0x28fbae10050>,
#  <Element tr at 0x28fbae10780>,
#  <Element tr at 0x28fbae122b0>,
#  <Element tr at 0x28fbae13980>,
#  <Element tr at 0x28fbae11c20>,
#  <Element tr at 0x28fbae12260>,
#  <Element tr at 0x28fbae11cc0>,
#  <Element tr at 0x28fbae11f90>,
#  <Element tr at 0x28fbae11fe0>,
#  <Element tr at 0x28fbae12710>,
#  <Element tr at 0x28fbae126c0>,
#  <Element tr at 0x28fbae12800>,
#  <Element tr at 0x28fbae12850>,
#  <Element tr at 0x28fbae12760>,
#  <Element tr at 0x28fbae11bd0>,
#  <Element tr at 0x28fbae11c70>,
#  <Element tr at 0x28fbae11ae0>,
#  <Element tr at 0x28fbae11d10>,
#  <Element tr at 0x28fbae137f0>,
#  <Element tr at 0x28fbae13fc0>,
#  <Element tr at 0x28fbae138e0>,
#  <Element tr at 0x28fbae13340>,
#  <Element tr at 0x28fbae13a70>,
#  <Element tr at 0x28fbae13520>,
#  <Element tr at 0x28fbae13570>,
#  <Element tr at 0x28fbae136b0>,
#  <Element tr at 0x28fbae13750>,
#  <Element tr at 0x28fbae13700>,
#  <Element tr at 0x28fbae134d0>,
#  <Element tr at 0x28fbae10f00>,
#  <Element tr at 0x28fbae133e0>,
#  <Element tr at 0x28fbae13480>,
#  <Element tr at 0x28fbae132f0>,
#  <Element tr at 0x28fbae13390>,
#  <Element tr at 0x28fbae13110>,
#  <Element tr at 0x28fbae132a0>,
#  <Element tr at 0x28fbae13250>,
#  <Element tr at 0x28fbae12e90>,
#  <Element tr at 0x28fbae12d00>,
#  <Element tr at 0x28fbae12ee0>,
#  <Element tr at 0x28fbae12f80>,
#  <Element tr at 0x28fbae12f30>,
#  <Element tr at 0x28fbae12fd0>,
#  <Element tr at 0x28fbae13070>,
#  <Element tr at 0x28fbae130c0>,
#  <Element tr at 0x28fbadea7b0>,
#  <Element tr at 0x28fbadea800>,
#  <Element tr at 0x28fbadea850>,
#  <Element tr at 0x28fbadeb520>,
#  <Element tr at 0x28fbade8140>,
#  <Element tr at 0x28fbadeb7a0>,
#  <Element tr at 0x28fbadebac0>,
#  <Element tr at 0x28fbade9270>,
#  <Element tr at 0x28fbade94f0>,
#  <Element tr at 0x28fbade95e0>,
#  <Element tr at 0x28fbade97c0>,
#  <Element tr at 0x28fbade9810>,
#  <Element tr at 0x28fbade9860>,
#  <Element tr at 0x28fbade9900>,
#  <Element tr at 0x28fbade9950>,
#  <Element tr at 0x28fbade99a0>,
#  <Element tr at 0x28fbade99f0>,
#  <Element tr at 0x28fbade9a40>,
#  <Element tr at 0x28fbadea030>,
#  <Element tr at 0x28fbadea440>,
#  <Element tr at 0x28fbadea4e0>,
#  <Element tr at 0x28fbadea990>,
#  <Element tr at 0x28fbadeaad0>,
#  <Element tr at 0x28fbadeab20>,
#  <Element tr at 0x28fbade98b0>,
#  <Element tr at 0x28fbade9e50>,
#  <Element tr at 0x28fbadea080>,
#  <Element tr at 0x28fbadea260>,
#  <Element tr at 0x28fbadea530>,
#  <Element tr at 0x28fbadea620>,
#  <Element tr at 0x28fbadea760>,
#  <Element tr at 0x28fbadea8f0>,
#  <Element tr at 0x28fbadeac10>,
#  <Element tr at 0x28fbadeacb0>,
#  <Element tr at 0x28fbadead00>,
#  <Element tr at 0x28fbadeb480>,
#  <Element tr at 0x28fbade80f0>,
#  <Element tr at 0x28fbade8dc0>,
#  <Element tr at 0x28fbadeaf80>,
#  <Element tr at 0x28fbade9680>,
#  <Element tr at 0x28fbadea8a0>,
#  <Element tr at 0x28fbadea940>,
#  <Element tr at 0x28fbadea170>,
#  <Element tr at 0x28fbadea1c0>,
#  <Element tr at 0x28fbadea210>,
#  <Element tr at 0x28fbadea2b0>,
#  <Element tr at 0x28fbadea300>,
#  <Element tr at 0x28fbadea490>,
#  <Element tr at 0x28fbade9bd0>,
#  <Element tr at 0x28fbade9c20>,
#  <Element tr at 0x28fbade9c70>,
#  <Element tr at 0x28fbade9cc0>,
#  <Element tr at 0x28fbade9db0>,
#  <Element tr at 0x28fbadea120>,
#  <Element tr at 0x28fbadea3f0>,
#  <Element tr at 0x28fbade9a90>,
#  <Element tr at 0x28fbade9e00>,
#  <Element tr at 0x28fbade9630>,
#  <Element tr at 0x28fbadeb930>,
#  <Element tr at 0x28fbade8640>,
#  <Element tr at 0x28fbade94a0>,
#  <Element tr at 0x28fbade9540>,
#  <Element tr at 0x28fbade8f50>,
#  <Element tr at 0x28fbade9040>,
#  <Element tr at 0x28fbade9090>,
#  <Element tr at 0x28fbade90e0>,
#  <Element tr at 0x28fbade9400>,
#  <Element tr at 0x28fbade9450>,
#  <Element tr at 0x28fbade9720>,
#  <Element tr at 0x28fbadeafd0>,
#  <Element tr at 0x28fbade89b0>,
#  <Element tr at 0x28fbadeb1b0>,
#  <Element tr at 0x28fbade8f00>,
#  <Element tr at 0x28fbade9220>,
#  <Element tr at 0x28fbade8960>,
#  <Element tr at 0x28fbadebc00>,
#  <Element tr at 0x28fbade84b0>,
#  <Element tr at 0x28fbade8c30>,
#  <Element tr at 0x28fbade8500>,
#  <Element tr at 0x28fbadeac60>,
#  <Element tr at 0x28fbade81e0>,
#  <Element tr at 0x28fbadeb5c0>,
#  <Element tr at 0x28fbade85a0>,
#  <Element tr at 0x28fbade8820>,
#  <Element tr at 0x28fbade8910>,
#  <Element tr at 0x28fbade8af0>,
#  <Element tr at 0x28fbade8370>,
#  <Element tr at 0x28fbade8550>,
#  <Element tr at 0x28fbadeb160>,
#  <Element tr at 0x28fbadeb840>,
#  <Element tr at 0x28fbadd7bb0>,
#  <Element tr at 0x28fbadd7ac0>,
#  <Element tr at 0x28fbb04f430>,
#  <Element tr at 0x28fbb04f390>,
#  <Element tr at 0x28fbb04f750>,
#  <Element tr at 0x28fbb04fa70>,
#  <Element tr at 0x28fbb04fd40>,
#  <Element tr at 0x28fbb04eee0>,
#  <Element tr at 0x28fbb04ee90>,
#  <Element tr at 0x28fbb04ed50>,
#  <Element tr at 0x28fbb04ed00>,
#  <Element tr at 0x28fbb04ecb0>,
#  <Element tr at 0x28fbb04f110>,
#  <Element tr at 0x28fbb04c640>,
#  <Element tr at 0x28fbb04f7a0>,
#  <Element tr at 0x28fbb04f6b0>,
#  <Element tr at 0x28fbb04f8e0>,
#  <Element tr at 0x28fbb04f890>,
#  <Element tr at 0x28fbb04fca0>,
#  <Element tr at 0x28fbb04ff20>,
#  <Element tr at 0x28fbb04fe80>,
#  <Element tr at 0x28fbb04f9d0>,
#  <Element tr at 0x28fbb04fbb0>,
#  <Element tr at 0x28fbb04f840>,
#  <Element tr at 0x28fbb04ea80>,
#  <Element tr at 0x28fbb04e170>,
#  <Element tr at 0x28fbb04def0>,
#  <Element tr at 0x28fbb04dcc0>,
#  <Element tr at 0x28fbb04d810>,
#  <Element tr at 0x28fbb04dae0>,
#  <Element tr at 0x28fbb04d9f0>,
#  <Element tr at 0x28fbb04d9a0>,
#  <Element tr at 0x28fbb04d950>,
#  <Element tr at 0x28fbb04d180>,
#  <Element tr at 0x28fbb04ce60>,
#  <Element tr at 0x28fbb04cd70>,
#  <Element tr at 0x28fbb04cc80>,
#  <Element tr at 0x28fbb04da40>,
#  <Element tr at 0x28fbb04d130>,
#  <Element tr at 0x28fbb04d0e0>,
#  <Element tr at 0x28fbb04d450>,
#  <Element tr at 0x28fbb04d400>,
#  <Element tr at 0x28fbb04d3b0>,
#  <Element tr at 0x28fbb04d360>,
#  <Element tr at 0x28fbb04d310>,
#  <Element tr at 0x28fbb04d270>,
#  <Element tr at 0x28fbb04d1d0>,
#  <Element tr at 0x28fbb04d680>,
#  <Element tr at 0x28fbb04d6d0>,
#  <Element tr at 0x28fbb04d770>,
#  <Element tr at 0x28fbb04d2c0>,
#  <Element tr at 0x28fbb04ddb0>,
#  <Element tr at 0x28fbb04dd10>,
#  <Element tr at 0x28fbb04e1c0>,
#  <Element tr at 0x28fbb04fcf0>,
#  <Element tr at 0x28fbb04f1b0>,
#  <Element tr at 0x28fbb04fed0>,
#  <Element tr at 0x28fbb04ffc0>,
#  <Element tr at 0x28fbb04fa20>,
#  <Element tr at 0x28fbb04f930>,
#  <Element tr at 0x28fbb04fd90>,
#  <Element tr at 0x28fbb04fb60>,
#  <Element tr at 0x28fbb04e850>,
#  <Element tr at 0x28fbb04cd20>,
#  <Element tr at 0x28fbb04ccd0>,
#  <Element tr at 0x28fbb04d040>,
#  <Element tr at 0x28fbb04cff0>,
#  <Element tr at 0x28fbb04cfa0>,
#  <Element tr at 0x28fbb04cf50>,
#  <Element tr at 0x28fbb04cf00>,
#  <Element tr at 0x28fbb04ce10>,
#  <Element tr at 0x28fbb04cdc0>,
#  <Element tr at 0x28fbb04d8b0>,
#  <Element tr at 0x28fbb04d860>,
#  <Element tr at 0x28fbb04d720>,
#  <Element tr at 0x28fbb04d7c0>,
#  <Element tr at 0x28fbb04d4a0>,
#  <Element tr at 0x28fbb04d090>,
#  <Element tr at 0x28fbb04ceb0>,
#  <Element tr at 0x28fbb04d900>,
#  <Element tr at 0x28fbb04d220>,
#  <Element tr at 0x28fbb04e990>,
#  <Element tr at 0x28fbb04ee40>,
#  <Element tr at 0x28fbb04edf0>,
#  <Element tr at 0x28fbb04f980>,
#  <Element tr at 0x28fbb04fb10>,
#  <Element tr at 0x28fbb04ff70>,
#  <Element tr at 0x28fbb04fc50>,
#  <Element tr at 0x28fbb04fe30>,
#  <Element tr at 0x28fbb04fde0>,
#  <Element tr at 0x28fbb04f5c0>,
#  <Element tr at 0x28fbb04fc00>,
#  <Element tr at 0x28fbb04e940>,
#  <Element tr at 0x28fbae6b8e0>,
#  <Element tr at 0x28fbae6b750>,
#  <Element tr at 0x28fbae6abc0>,
#  <Element tr at 0x28fbae6a940>,
#  <Element tr at 0x28fbae6ac10>,
#  <Element tr at 0x28fbae6b160>,
#  <Element tr at 0x28fbae6b610>,
#  <Element tr at 0x28fbae6b430>,
#  <Element tr at 0x28fbae6b660>,
#  <Element tr at 0x28fbb154410>,
#  <Element tr at 0x28fbb156120>,
#  <Element tr at 0x28fbb155040>,
#  <Element tr at 0x28fbb155590>,
#  <Element tr at 0x28fbb154640>,
#  <Element tr at 0x28fbb157ac0>,
#  <Element tr at 0x28fbb157020>,
#  <Element tr at 0x28fbb157930>,
#  <Element tr at 0x28fbaff5a90>,
#  <Element tr at 0x28fbaff5310>,
#  <Element tr at 0x28fbaff51d0>,
#  <Element tr at 0x28fbaff7b10>,
#  <Element tr at 0x28fbaff7a70>,
#  <Element tr at 0x28fbaff4d20>,
#  <Element tr at 0x28fbaff5ae0>,
#  <Element tr at 0x28fbaff5860>,
#  <Element tr at 0x28fbaff5360>,
#  <Element tr at 0x28fbaff6d00>,
#  <Element tr at 0x28fbaff55e0>,
#  <Element tr at 0x28fbaff5680>,
#  <Element tr at 0x28fbaff5400>,
#  <Element tr at 0x28fbaff59a0>,
#  <Element tr at 0x28fbae43a70>,
#  <Element tr at 0x28fbae43f20>,
#  <Element tr at 0x28fbae40870>,
#  <Element tr at 0x28fbae439d0>,
#  <Element tr at 0x28fbae433e0>,
#  <Element tr at 0x28fbae42850>,
#  <Element tr at 0x28fbae41e50>,
#  <Element tr at 0x28fbae41c20>,
#  <Element tr at 0x28fbae43e80>,
#  <Element tr at 0x28fbae42760>,
#  <Element tr at 0x28fbae432f0>,
#  <Element tr at 0x28fbae43480>,
#  <Element tr at 0x28fbae43980>,
#  <Element tr at 0x28fbad80460>,
#  <Element tr at 0x28fbad80be0>,
#  <Element tr at 0x28fbad80b90>,
#  <Element tr at 0x28fbad80b40>,
#  <Element tr at 0x28fbad80910>,
#  <Element tr at 0x28fbad805f0>,
#  <Element tr at 0x28fbad809b0>,
#  <Element tr at 0x28fbad82d50>,
#  <Element tr at 0x28fbad82670>,
#  <Element tr at 0x28fbad82990>,
#  <Element tr at 0x28fbad83930>,
#  <Element tr at 0x28fbad80d70>,
#  <Element tr at 0x28fbad835c0>,
#  <Element tr at 0x28fbad832a0>,
#  <Element tr at 0x28fbad839d0>,
#  <Element tr at 0x28fbad828a0>,
#  <Element tr at 0x28fbad83a70>,
#  <Element tr at 0x28fbad83480>,
#  <Element tr at 0x28fbad829e0>,
#  <Element tr at 0x28fbad83570>,
#  <Element tr at 0x28fbad82b70>,
#  <Element tr at 0x28fbad82710>,
#  <Element tr at 0x28fbad82e40>,
#  <Element tr at 0x28fbad82f30>,
#  <Element tr at 0x28fbad82ee0>,
#  <Element tr at 0x28fbad80d20>,
#  <Element tr at 0x28fbad81130>,
#  <Element tr at 0x28fbad80dc0>,
#  <Element tr at 0x28fbad833e0>,
#  <Element tr at 0x28fbad83390>,
#  <Element tr at 0x28fbad83340>,
#  <Element tr at 0x28fbad837f0>,
#  <Element tr at 0x28fbad82f80>,
#  <Element tr at 0x28fbad800f0>,
#  <Element tr at 0x28fbad80190>,
#  <Element tr at 0x28fbad83020>,
#  <Element tr at 0x28fbad80140>,
#  <Element tr at 0x28fbad830c0>,
#  <Element tr at 0x28fbad801e0>,
#  <Element tr at 0x28fbad805a0>,
#  <Element tr at 0x28fbad80640>,
#  <Element tr at 0x28fbad80690>,
#  <Element tr at 0x28fbad807d0>,
#  <Element tr at 0x28fbad80a50>,
#  <Element tr at 0x28fbad82210>,
#  <Element tr at 0x28fbad80a00>,
#  <Element tr at 0x28fbad80230>,
#  <Element tr at 0x28fbad80c30>,
#  <Element tr at 0x28fbad821c0>,
#  <Element tr at 0x28fbad82260>,
#  <Element tr at 0x28fbad823a0>,
#  <Element tr at 0x28fbad823f0>,
#  <Element tr at 0x28fbad83c00>,
#  <Element tr at 0x28fbad83c50>,
#  <Element tr at 0x28fbad83d40>,
#  <Element tr at 0x28fbad83d90>,
#  <Element tr at 0x28fbad83de0>,
#  <Element tr at 0x28fbad83f20>,
#  <Element tr at 0x28fbad83f70>,
#  <Element tr at 0x28fbad828f0>,
#  <Element tr at 0x28fbad82c10>,
#  <Element tr at 0x28fbad82170>,
#  <Element tr at 0x28fbad824e0>,
#  <Element tr at 0x28fbad825d0>,
#  <Element tr at 0x28fbad81310>,
#  <Element tr at 0x28fbad81360>,
#  <Element tr at 0x28fbad81180>,
#  <Element tr at 0x28fbad811d0>,
#  <Element tr at 0x28fbad81090>,
#  <Element tr at 0x28fbad810e0>,
#  <Element tr at 0x28fbad81040>,
#  <Element tr at 0x28fbad80ff0>,
#  <Element tr at 0x28fbad80f00>,
#  <Element tr at 0x28fbad80fa0>,
#  <Element tr at 0x28fbad80cd0>,
#  <Element tr at 0x28fbad80c80>,
#  <Element tr at 0x28fbad80e10>,
#  <Element tr at 0x28fbad80e60>,
#  <Element tr at 0x28fbad80eb0>,
#  <Element tr at 0x28fbad822b0>,
#  <Element tr at 0x28fbad82440>,
#  <Element tr at 0x28fbad82ad0>,
#  <Element tr at 0x28fbad82940>,
#  <Element tr at 0x28fbad82850>,
#  <Element tr at 0x28fbad82800>,
#  <Element tr at 0x28fbad836b0>,
#  <Element tr at 0x28fbad83b10>,
#  <Element tr at 0x28fbad83a20>,
#  <Element tr at 0x28fbad81f40>,
#  <Element tr at 0x28fbad82030>,
#  ...]

# %% [markdown]
# ### 指定節點文字相符：找出文字是 Ivysaur 的節點
# - Hint: 使用 `tree.xpath('//<tag_name>[text()="some_string"]')`

# %%
tree.xpath('//a[text()="Ivysaur"]')[0].text
# Out:
# 'Ivysaur'

# %% [markdown]
# ### 找出屬性包含部分文字的節點：找出各種類型的寶可夢種類標籤
#
# - 包含： `tree.xpath('//<tag_name>[contains(<attribute>, <attribute_value>)]')`
# - 不包含： `tree.xpath('//<tag_name>[not(contains(<attribute>, <attribute_value>))]')`

# %%
# 找出各種類型的寶可夢種類標籤(GRASS, POISON, ...)，用 set 過濾出不重複種類有哪幾種

# Hint: set(tree.xpath('//a[________(@_____, "type-")]/text()'))

set(tree.xpath('//a[contains(@class, "type-")]/text()'))
# Out:
# {'Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water'}

# %% [markdown]
# ### 將資訊組成表格

# %%
# Hint: 
# header_cols = [col.xpath(".//____()")[0] for col in header]
# row_values = [["".join(col.xpath('.//____()')) for col in row.xpath('.//__')] for row in body_rows]


header_cols = [col.xpath(".//text()")[0] for col in header]
row_values = [["".join(col.xpath('.//text()')) for col in row.xpath('.//td')] for row in body_rows]

# %%
row_values[0]
# Out:
# ['\n\t\n\t\n0001',
#  'Bulbasaur',
#  'Grass Poison',
#  '318',
#  '45',
#  '49',
#  '49',
#  '65',
#  '65',
#  '45']

# %%
import pandas as pd
df = pd.DataFrame(row_values, columns=header_cols)
df["Type"] = df["Type"].apply(lambda x: x.strip().split(" "))
df
# Out:
#                    #                     Name              Type Total   HP  \
# 0     \n\t\n\t\n0001                Bulbasaur   [Grass, Poison]   318   45
# 1     \n\t\n\t\n0002                  Ivysaur   [Grass, Poison]   405   60
# 2     \n\t\n\t\n0003                 Venusaur   [Grass, Poison]   525   80
# 3     \n\t\n\t\n0003   Venusaur Mega Venusaur   [Grass, Poison]   625   80
# 4     \n\t\n\t\n0004               Charmander            [Fire]   309   39
# ...              ...                      ...               ...   ...  ...
# 1210  \n\t\n\t\n1023               Iron Crown  [Steel, Psychic]   590   90
# 1211  \n\t\n\t\n1024    Terapagos Normal Form          [Normal]   450   90
# 1212  \n\t\n\t\n1024  Terapagos Terastal Form          [Normal]   600   95
# 1213  \n\t\n\t\n1024   Terapagos Stellar Form          [Normal]   700  160
# 1214  \n\t\n\t\n1025                Pecharunt   [Poison, Ghost]   600   88
#
#      Attack Defense Sp. Atk Sp. Def Speed
# 0        49      49      65      65    45
# 1        62      63      80      80    60
# 2        82      83     100     100    80
# 3       100     123     122     120    80
# 4        52      43      60      50    65
# ...     ...     ...     ...     ...   ...
# 1210     72     100     122     108    98
# 1211     65      85      65      85    60
# 1212     95     110     105     110    85
# 1213    105     110     130     110    85
# 1214     88     160      88      88    88
#
# [1215 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1215 entries, 0 to 1214
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   #        1215 non-null   object
#  1   Name     1215 non-null   object
#  2   Type     1215 non-null   object
#  3   Total    1215 non-null   object
#  4   HP       1215 non-null   object
#  5   Attack   1215 non-null   object
#  6   Defense  1215 non-null   object
#  7   Sp. Atk  1215 non-null   object
#  8   Sp. Def  1215 non-null   object
#  9   Speed    1215 non-null   object
# dtypes: object(10)
# memory usage: 95.1+ KB
