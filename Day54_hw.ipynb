# %% [markdown]
# # 加速：非同步爬蟲
#
# * 了解非同步爬蟲加速原理與實作

# %% [markdown]
# ## 作業目標
#
# * 比較一下非同步爬蟲跟多線程爬蟲的差異是什麼？各自的優缺點為何？（圖文回答即可）

# %% [markdown]
# 比較項目	多線程（Threading）	非同步（Asyncio）
# 建立資源	較重（每個 thread 都要記憶體）	較輕（協程更省資源）
# 實作難度	中（容易理解）	中～高（需要理解 async/await）
# 效能表現	好（I/O 密集時很有效）	更好（大量 I/O 更穩定）
# 相容性	舊框架支援佳（如 Flask）	某些舊框架不支援 async
