# %% [markdown]
# # 實務上的爬蟲與挑戰
#
#
# * 實務上爬蟲可能遇到的問題有哪些
# * 淺談常見防爬蟲機制與處理策略
# * 如何建構一個可以自動持續更新的爬蟲程式

# %% [markdown]
# ## 作業目標
#
# * （簡答題）試著舉出一到三個爬蟲可能會遇到的問題導致無法抓取的？

# %% [markdown]
# ### （簡答題）試著舉出一到三個爬蟲可能會遇到的問題導致無法抓取的？

# %%
網站反爬蟲機制：如驗證碼、IP封鎖、User-Agent檢查等，會阻擋非人類訪問。

JavaScript動態載入內容：資料不是直接寫在HTML中，而是透過JS載入，需使用Selenium等工具模擬瀏覽器行為才能抓取。

網站結構變動：目標網站的HTML結構若變更，原本的爬蟲程式碼會抓不到正確資料或出錯。
# Out:
# '\nYour Input Here\n'
